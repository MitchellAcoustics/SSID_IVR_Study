# %%
import importlib
from hamilton import driver
from pathlib import Path

from ivr_utils import ivr_utils, cityseg_utils

# %%
# Use this to reload the module after making changes to it.
importlib.reload(ivr_utils)
dr = driver.Builder().with_modules(ivr_utils, cityseg_utils).with_cache().build()

# %%
final_vars = [
    "mp4_conversion",
    "output_video_paths",
    "save_gaze_data",
]
inputs = {
    "participant_id": "P43",
    "n_frames_proc": None,
    "eyetracking_dir": "/Volumes/ritd-ag-project-rd01wq-tober63/SSID IVR Study 1/Eyetracking",
    "output_dir": "/Users/mitch/Documents/UCL/Papers_2025/SSID_IVR_Study/data/output/2025-04-15-test",
}

dr.visualize_execution(final_vars, inputs=inputs)

# %%
from pprint import pprint

pprint(dr.cache.logs(level="info"))
# Out:
# {'f71cc57c-6fe1-48cd-9177-1e559e007230': [CachingEvent(run_id='f71cc57c-6fe1-48cd-9177-1e559e007230',
#                                                        actor='adapter',
#                                                        event_type=<CachingEventType.EXECUTE_NODE: 'execute_node'>,
#                                                        node_name='participant_file_paths',
#                                                        task_id=None,
#                                                        msg=None,
#                                                        value=None,
#                                                        timestamp=1744807053.524823),
#                                           CachingEvent(run_id='f71cc57c-6fe1-48cd-9177-1e559e007230',
#                                                        actor='adapter',
#                                                        event_type=<CachingEventType.EXECUTE_NODE: 'execute_node'>,
#                                                        node_name='mp4_conversion',
#                                                        task_id=None,
#                                                        msg=None,
#                                                        value=None,
#                                                        timestamp=1744807054.212208),
#                                           CachingEvent(run_id='f71cc57c-6fe1-48cd-9177-1e559e007230',
#                                                        actor='adapter',
#                                                        event_type=<CachingEventType.EXECUTE_NODE: 'execute_node'>,
#                                                        node_name='output_video_paths',
#                                                        task_id=None,
#                                                        msg=None,
#                                                        value=None,
#                                                        timestamp=1744807054.222013),
#                                           CachingEvent(run_id='f71cc57c-6fe1-48cd-9177-1e559e007230',
#                                                        actor='adapter',
#                                                        event_type=<CachingEventType.EXECUTE_NODE: 'execute_node'>,
#                                                        node_name='participant_points',
#                                                        task_id=None,
#                                                        msg=None,
#                                                        value=None,
#                                                        timestamp=1744807057.132297),
#                                           CachingEvent(run_id='f71cc57c-6fe1-48cd-9177-1e559e007230',
#                                                        actor='adapter',
#                                                        event_type=<CachingEventType.EXECUTE_NODE: 'execute_node'>,
#                                                        node_name='process_video',
#                                                        task_id=None,
#                                                        msg=None,
#                                                        value=None,
#                                                        timestamp=1744807057.586633),
#                                           CachingEvent(run_id='f71cc57c-6fe1-48cd-9177-1e559e007230',
#                                                        actor='adapter',
#                                                        event_type=<CachingEventType.EXECUTE_NODE: 'execute_node'>,
#                                                        node_name='save_gaze_data',
#                                                        task_id=None,
#                                                        msg=None,
#                                                        value=None,
#                                                        timestamp=1744807057.590003)]}

# %%
res = dr.execute(final_vars, inputs=inputs)

# %%
dr.cache.view_run(run_id=dr.cache.last_run_id)
